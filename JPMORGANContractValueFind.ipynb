# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = r"C:\Users\Dell\Downloads\Nat_Gas (3).csv"
df = pd.read_csv(file_path)

df.columns = df.columns.str.strip().str.lower()

df["dates"] = pd.to_datetime(df["dates"])
df.set_index("dates", inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10568\1613366828.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["dates"] = pd.to_datetime(df["dates"])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.loc[dates, "prices"]
#
# NameError: name 'dates' is not defined
